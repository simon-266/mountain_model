# %% [markdown]
# # Creating a model to fill Null values into a Mountain Dataset

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from keras import layers
import geopy
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Fetch data from files

# %%
train = pd.read_csv("data/Mountain.csv")
unfilled = pd.read_csv("data/unfilled.csv")

# %% [markdown]
# ## Information to the Data

# %%
train.sample(5)
# Out:
#                      Name  Height        MountainRange     Country
# 323         Malika Parbat  5290.0             Himalaya    Pakistan
# 259                Shayaz  6045.0            Karakoram    Pakistan
# 1085       Guadalupe Peak  2667.0  Guadalupe Mountains         USA
# 102              Karjiang  7221.0             Himalaya       China
# 610   Vladimir Putin Peak  4446.0            Tian Shan  Kyrgyzstan

# %%
unfilled.sample(5)
# Out:
#    MountainID          Name  Height  FirstAcent  Mountains
# 1           2            K2    8611  1954-07-31  Karakorum
# 5           8   Mount Blanc    4810  1786-08-08        NaN
# 3           5  Nanga Parbat    8125  1956-05-09   Himalaya
# 7          10        Makalu    8485  2009-02-09   Himalaya
# 6           9       Cho Oyu    8188  1985-02-12   Himalaya

# %%
train.isna().sum()
# Out:
# Name              0
# Height            0
# MountainRange     0
# Country          45
# dtype: int64

# %%
unfilled.isna().sum()
# Out:
# MountainID    0
# Name          0
# Height        0
# FirstAcent    0
# Mountains     3
# dtype: int64

# %% [markdown]
# ## Prepare the Data to model

# %%
mask_nan = unfilled['Mountains'].isnull()
predict = unfilled.loc[mask_nan, ['MountainID', 'Height', 'Name']]

# %%
predict.head()
# Out:
#    MountainID  Height         Name
# 0           1    2962    Zugspitze
# 2           4    2522   Hoher Göll
# 5           8    4810  Mount Blanc

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Silly-Mountain-Model")
def get_lat_lon(name, geolocator):
    try:
        location = geolocator.geocode(name)
        if location:
            return pd.Series((location.latitude, location.longitude))
        else:
            return pd.Series((None, None))
    except Exception as e:
        print(f"Error with: '{name}': {e}")
        return pd.Series((None, None))

# %%
train[['latitude', 'longitude']] = train['Name'].apply(lambda x: get_lat_lon(x, geolocator))
train = train.drop(['Name', 'Country'], axis=1)
predict[['latitude', 'longitude']] = predict['Name'].apply(lambda x: get_lat_lon(x, geolocator))
# Out:
# Error with: 'Gasherbrum I': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Gasherbrum+I&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error with: 'Laram Q'awa (Charaña)': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Laram+Q%27awa+%28Chara%C3%B1a%29&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error with: 'Dufourspitze (Monte Rosa)': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Dufourspitze+%28Monte+Rosa%29&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error with: 'Ludwigshöhe (Monte Rosa)': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Ludwigsh%C3%B6he+%28Monte+Rosa%29&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error with: 'Velky Rozsutec': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Velky+Rozsutec&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error with: 'Doi Ian': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Doi+Ian&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error with: 'Mountain La Terre (Mont La Terre)': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Mountain+La+Terre+%28Mont+La+Terre%29&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
train = train.dropna()

# %%
train.head()
# Out:
#     Height MountainRange   latitude  longitude
# 0  8848.86      Himalaya  27.988061  86.925210
# 1  8611.00     Karakorum  35.881682  76.513331
# 2  8586.00      Himalaya  27.703011  88.147477
# 3  8516.00      Himalaya  27.961986  86.932504
# 4  8485.00      Himalaya  27.891438  87.088440

# %%
predict_val = predict[['Height', 'latitude', 'longitude']]

# %%
predict_val.head()
# Out:
#    Height   latitude   longitude
# 0    2962  47.421215   10.986297
# 2    2522  47.593926   13.067141
# 5    4810 -26.814444  152.878611

# %% [markdown]
# ## Modelbuilding

# %%
label_encoder = LabelEncoder()
classes = train['MountainRange'].nunique()
train['MountainRange_encoded'] = label_encoder.fit_transform(train['MountainRange'])
y_train_encoded = tf.keras.utils.to_categorical(train['MountainRange_encoded'], num_classes=classes)
x_train = train[['Height', 'latitude', 'longitude']].values
input_layer = tf.keras.Input(shape=(3,), name='input')
dense_layer = layers.Dense(64, activation='relu')(input_layer)
dense_layer_2 = layers.Dense(64, activation='relu')(dense_layer)
output_layer = layers.Dense(classes, activation='softmax', name='output')(dense_layer_2)
model = keras.Model(inputs=input_layer, outputs=output_layer, name='Mountain_model')
model.summary()
# Out:
# Model: "Mountain_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 3)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 411)            │        26,715 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,131 (121.61 KB)
#  Trainable params: 31,131 (121.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train , y_train_encoded, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3873 - loss: 2.1242
# Epoch 2/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3619 - loss: 2.1722
# Epoch 3/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3874 - loss: 2.0949
# Epoch 4/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3890 - loss: 2.1299
# Epoch 5/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3684 - loss: 2.2048
# Epoch 6/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3727 - loss: 2.2340
# Epoch 7/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4040 - loss: 2.0391
# Epoch 8/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4022 - loss: 2.0830
# Epoch 9/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3785 - loss: 2.1200
# Epoch 10/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3612 - loss: 2.1839
# Epoch 11/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4137 - loss: 2.0499
# Epoch 12/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3747 - loss: 2.1123
# Epoch 13/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4072 - loss: 2.0384
# Epoch 14/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3833 - loss: 2.0946
# Epoch 15/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4187 - loss: 2.0102
# Epoch 16/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3965 - loss: 2.0586
# Epoch 17/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4068 - loss: 2.0330
# Epoch 18/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3966 - loss: 2.0332
# Epoch 19/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4030 - loss: 1.9998
# Epoch 20/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3821 - loss: 2.1484
# Epoch 21/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3876 - loss: 2.0643
# Epoch 22/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3890 - loss: 2.0370
# Epoch 23/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3817 - loss: 2.1083
# Epoch 24/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3911 - loss: 2.0447
# Epoch 25/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3805 - loss: 2.0927
# Epoch 26/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4080 - loss: 1.9849
# Epoch 27/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3750 - loss: 2.0923
# Epoch 28/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4074 - loss: 2.0492
# Epoch 29/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4185 - loss: 1.9724
# Epoch 30/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3957 - loss: 2.0659
# Epoch 31/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3756 - loss: 2.0733
# Epoch 32/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3830 - loss: 2.1116
# Epoch 33/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3860 - loss: 2.1064
# Epoch 34/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3838 - loss: 2.0446
# Epoch 35/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4145 - loss: 2.0043
# Epoch 36/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3838 - loss: 2.0487
# Epoch 37/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4103 - loss: 1.9711
# Epoch 38/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4262 - loss: 1.9155
# Epoch 39/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4021 - loss: 2.0365
# Epoch 40/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3970 - loss: 2.0384
# Epoch 41/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3925 - loss: 2.0380
# Epoch 42/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3838 - loss: 2.0229
# Epoch 43/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4188 - loss: 1.9838
# Epoch 44/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4130 - loss: 1.9792
# Epoch 45/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4017 - loss: 2.0065
# Epoch 46/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4146 - loss: 1.9800
# Epoch 47/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4286 - loss: 1.9519
# Epoch 48/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3794 - loss: 2.0988
# Epoch 49/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4230 - loss: 1.9348
# Epoch 50/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4120 - loss: 1.9787
# Epoch 51/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4385 - loss: 1.8898
# Epoch 52/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3907 - loss: 1.9972
# Epoch 53/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4129 - loss: 2.0136
# Epoch 54/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4158 - loss: 1.9607
# Epoch 55/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4275 - loss: 1.9542
# Epoch 56/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.